# %% [markdown]
# # OOPS Concepts

# %% [markdown]
# ![image.png](attachment:image.png)
#
# we are using OOPS concepts to create objects

# %% [markdown]
# ![image.png](attachment:image.png)
#
# same==>
#
# apache tomcat ==> char => version, config,webapps etx (attributes,variables)
#
#    functions ==> creting static pages (functions())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1. To Group Related Functions(methods)
# Req : code
# app1 related code ==> 100 functions
# app2 related code ==> 100 functions
# you are performing an operation that requires to call a function related to app2 related
# ?
# Ans :
# we can call using a fun name ? ==> python checks 200 functions and checks the name
#       ==> if matches it will run
#       ==> but it needs to check 200 function names
# objects ==> create 2 ==> app1 object
#                          app2 object
#      we are calling a function say colour() ==> app2 (object has a block seperately)
#   we can do this by app2.colour()                   {
#   by doing this we can skip app1 related functions     -----
#   this is like grouping functions as app1 and app2      ------
#                                                           ----- }

# %% [raw]
# 2. Create a Blueprint/template
# Ex: if you are to file a tax to a govt
#      govt ==> gives some forms/template to you to fill
#      we will fill and file that ===> e filing
#  same way ===> templates/blueprints are used to create objects
#           ===> templates are called classes

# %% [raw]
# 3. OOps is a concept where we merge both functions and characteristics are packed into a
#       object (oops are useful in development side, automation ==> rarely uses )
